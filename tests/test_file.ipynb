# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('C:\\Users\\ymj\\visual-aid-project\\data\\dummyimu.csv')
plt.plot(df['time'], df['accel_z'], label='accel_z')
plt.xlabel('Time (s)')
plt.ylabel('Acceleration Z (m/s²)')
plt.title('IMU Z축 sine wave 시뮬레이션')
plt.legend()
plt.show()
# Out:
# c:\Users\ymj\visual-aid-project\capstone\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ymj\visual-aid-project\capstone\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ymj\visual-aid-project\capstone\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48044 (\N{HANGUL SYLLABLE MYUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ymj\visual-aid-project\capstone\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47112 (\N{HANGUL SYLLABLE RE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
